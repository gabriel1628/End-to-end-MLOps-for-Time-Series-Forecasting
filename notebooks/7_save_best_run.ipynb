# %%
import mlflow
from mlflow import MlflowClient
from dotenv import dotenv_values

# %%
import sys

env_vars = dotenv_values("../.env")
sys.path.append(f"{env_vars['WORKING_DIR']}")
from utils import load_config

config = load_config("../config/development/config.yaml")

# %% [markdown]
# From a terminal, run:
# ```
# mlflow server --host 127.0.0.1 --port 5000
# ```

# %%
client = MlflowClient(
    tracking_uri=env_vars["MLFLOW_TRACKING_URI"],
)

experiment_name = f"Enefit DataV1 lightgbm HpoConfigV1"
experiment = client.get_experiment_by_name(experiment_name)
experiment_id = experiment.experiment_id
runs_df = mlflow.search_runs([experiment_id])
runs_df.head()
# Out:
#                              run_id       experiment_id    status  \
# 0  54560700f31343be81d3065110ba6d87  215806994480999889  FINISHED
# 1  8c1446a5f1424e06a1febd5163a17330  215806994480999889  FINISHED
# 2  6ce5f9152766473186623e9ad218164b  215806994480999889  FINISHED
#
#                                         artifact_uri  \
# 0  mlflow-artifacts:/215806994480999889/54560700f...
# 1  mlflow-artifacts:/215806994480999889/8c1446a5f...
# 2  mlflow-artifacts:/215806994480999889/6ce5f9152...
#
#                         start_time                         end_time  \
# 0 2025-05-03 06:53:28.191000+00:00 2025-05-03 06:53:35.628000+00:00
# 1 2025-05-03 05:51:55.345000+00:00 2025-05-03 05:52:06.041000+00:00
# 2 2025-04-24 14:24:36.886000+00:00 2025-04-24 14:24:42.042000+00:00
#
#    metrics.test_mae  metrics.training_duration  metrics.train_mae  \
# 0        276.514219                   0.631784         267.450256
# 1        103.473742                   1.569685          63.773141
# 2        277.246492                   0.709642         267.962692
#
#   params.max_depth params.feature_fraction params.num_trees params.num_leaves  \
# 0                6      0.3962723889353149                8                24
# 1             None                    None             None              None
# 2                6      0.3962723889353149                8                24
#
#   params.learning_rate tags.mlflow.user                   tags.mlflow.runName  \
# 0  0.09906308908786306          gabriel      TrialNumber35-20250503T065327UTC
# 1                 None          gabriel  DefaultParameters-20250503T055155UTC
# 2  0.09906308908786306          gabriel      TrialNumber35-20250424T142435UTC
#
#   tags.mlflow.source.name                      tags.mlflow.log-model.history  \
# 0                train.py  [{"run_id": "54560700f31343be81d3065110ba6d87"...
# 1                train.py  [{"run_id": "8c1446a5f1424e06a1febd5163a17330"...
# 2                train.py  [{"run_id": "6ce5f9152766473186623e9ad218164b"...
#
#               tags.mlflow.source.git.commit tags.mlflow.source.type
# 0  da8acbc0b8c1c3f7b3fbae9a652bfbd61a8ef941                   LOCAL
# 1  da8acbc0b8c1c3f7b3fbae9a652bfbd61a8ef941                   LOCAL
# 2  b3988f18ead5caa415f3d9f2930d395ff5f61fef                   LOCAL

# %%
sorted_runs_df = runs_df.sort_values(by="metrics.test_mae", ascending=True)
sorted_runs_df.head()
# Out:
#                              run_id       experiment_id    status  \
# 1  8c1446a5f1424e06a1febd5163a17330  215806994480999889  FINISHED
# 0  54560700f31343be81d3065110ba6d87  215806994480999889  FINISHED
# 2  6ce5f9152766473186623e9ad218164b  215806994480999889  FINISHED
#
#                                         artifact_uri  \
# 1  mlflow-artifacts:/215806994480999889/8c1446a5f...
# 0  mlflow-artifacts:/215806994480999889/54560700f...
# 2  mlflow-artifacts:/215806994480999889/6ce5f9152...
#
#                         start_time                         end_time  \
# 1 2025-05-03 05:51:55.345000+00:00 2025-05-03 05:52:06.041000+00:00
# 0 2025-05-03 06:53:28.191000+00:00 2025-05-03 06:53:35.628000+00:00
# 2 2025-04-24 14:24:36.886000+00:00 2025-04-24 14:24:42.042000+00:00
#
#    metrics.test_mae  metrics.training_duration  metrics.train_mae  \
# 1        103.473742                   1.569685          63.773141
# 0        276.514219                   0.631784         267.450256
# 2        277.246492                   0.709642         267.962692
#
#   params.max_depth params.feature_fraction params.num_trees params.num_leaves  \
# 1             None                    None             None              None
# 0                6      0.3962723889353149                8                24
# 2                6      0.3962723889353149                8                24
#
#   params.learning_rate tags.mlflow.user                   tags.mlflow.runName  \
# 1                 None          gabriel  DefaultParameters-20250503T055155UTC
# 0  0.09906308908786306          gabriel      TrialNumber35-20250503T065327UTC
# 2  0.09906308908786306          gabriel      TrialNumber35-20250424T142435UTC
#
#   tags.mlflow.source.name                      tags.mlflow.log-model.history  \
# 1                train.py  [{"run_id": "8c1446a5f1424e06a1febd5163a17330"...
# 0                train.py  [{"run_id": "54560700f31343be81d3065110ba6d87"...
# 2                train.py  [{"run_id": "6ce5f9152766473186623e9ad218164b"...
#
#               tags.mlflow.source.git.commit tags.mlflow.source.type
# 1  da8acbc0b8c1c3f7b3fbae9a652bfbd61a8ef941                   LOCAL
# 0  da8acbc0b8c1c3f7b3fbae9a652bfbd61a8ef941                   LOCAL
# 2  b3988f18ead5caa415f3d9f2930d395ff5f61fef                   LOCAL

# %%
best_run = sorted_runs_df.iloc[0]
best_run_id = best_run["run_id"]
best_run_id
# Out:
# '8c1446a5f1424e06a1febd5163a17330'

# %%
import mlflow

logged_model = f"runs:/{best_run_id}/lightgbm"

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)

# # Predict on a Pandas DataFrame.
# import pandas as pd

# loaded_model.predict(pd.DataFrame(data))
# Out:
# Downloading artifacts:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
loaded_model
# Out:
# mlflow.pyfunc.loaded_model:
#   artifact_path: lightgbm
#   flavor: mlflow.lightgbm
#   run_id: 8c1446a5f1424e06a1febd5163a17330

# %%
loaded_model.get_raw_model()
# Out:
# LGBMRegressor(random_state=0)

# %%
import joblib
from utils import create_dir

# Create the models directory if it doesn't exist
create_dir("models")

# Save the model to a file
with open(f"models/{config['model_name']}.joblib", "wb") as f:
    joblib.dump(loaded_model, f)
# Out:
# Directory 'models' already exists.

# %%
# Load the model from the file
with open(f"models/{config['model_name']}.joblib", "rb") as f:
    loaded_model = joblib.load(f)

# %%
loaded_model
# Out:
# mlflow.pyfunc.loaded_model:
#   artifact_path: lightgbm
#   flavor: mlflow.lightgbm
#   run_id: 8c1446a5f1424e06a1febd5163a17330

# %%
import json

metadata = best_run.to_json(indent=4)
with open(f"models/{config['model_name']}_metadata.json", "w") as f:
    f.write(metadata)

# %%
with open(f"models/{config['model_name']}_metadata.json", "r") as f:
    metadata = json.load(f)
metadata
# Out:
# {'run_id': '8c1446a5f1424e06a1febd5163a17330',
#  'experiment_id': '215806994480999889',
#  'status': 'FINISHED',
#  'artifact_uri': 'mlflow-artifacts:/215806994480999889/8c1446a5f1424e06a1febd5163a17330/artifacts',
#  'start_time': 1746251515345,
#  'end_time': 1746251526041,
#  'metrics.test_mae': 103.4737424393,
#  'metrics.training_duration': 1.5696849823,
#  'metrics.train_mae': 63.7731407043,
#  'params.max_depth': None,
#  'params.feature_fraction': None,
#  'params.num_trees': None,
#  'params.num_leaves': None,
#  'params.learning_rate': None,
#  'tags.mlflow.user': 'gabriel',
#  'tags.mlflow.runName': 'DefaultParameters-20250503T055155UTC',
#  'tags.mlflow.source.name': 'train.py',
#  'tags.mlflow.log-model.history': '[{"run_id": "8c1446a5f1424e06a1febd5163a17330", "artifact_path": "lightgbm", "utc_time_created": "2025-05-03 05:52:00.433893", "model_uuid": "ddbd0a354b8640859eef85d3addb30e7", "flavors": {"python_function": {"loader_module": "mlflow.lightgbm", "python_version": "3.10.11", "data": "model.pkl", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "lightgbm": {"lgb_version": "4.5.0", "data": "model.pkl", "model_class": "lightgbm.sklearn.LGBMRegressor", "code": null}}}]',
#  'tags.mlflow.source.git.commit': 'da8acbc0b8c1c3f7b3fbae9a652bfbd61a8ef941',
#  'tags.mlflow.source.type': 'LOCAL'}
