# %%
import mlflow
from mlflow import MlflowClient
from dotenv import dotenv_values

# %%
import sys

env_vars = dotenv_values("../.env")
sys.path.append(f"{env_vars['WORKING_DIR']}")
from utils import load_config, save_config

config = load_config("../config/development/config.yaml")

# %% [markdown]
# # Retrieve runs

# %% [markdown]
# From a terminal, in the same repo as your mlruns directory, run:
# ```
# mlflow server --host 127.0.0.1 --port 5000
# ```

# %%
client = MlflowClient(
    tracking_uri=env_vars["MLFLOW_TRACKING_URI"],
)

experiment_name = f"Enefit DataV1 lightgbm HpoConfigV1"
experiment = client.get_experiment_by_name(experiment_name)
experiment_id = experiment.experiment_id
runs_df = mlflow.search_runs([experiment_id])
runs_df.head()
# Out:
#                              run_id       experiment_id    status  \
# 0  37cff3aa004b4ce39824c97d3f957fb5  255253755991586970  FINISHED
# 1  1ffaae870c4041edabeb7a2041cfe926  255253755991586970  FINISHED
#
#                                         artifact_uri  \
# 0  mlflow-artifacts:/255253755991586970/37cff3aa0...
# 1  mlflow-artifacts:/255253755991586970/1ffaae870...
#
#                         start_time                         end_time  \
# 0 2025-05-04 06:40:02.945000+00:00 2025-05-04 06:40:13.082000+00:00
# 1 2025-05-04 06:32:59.722000+00:00 2025-05-04 06:33:09.335000+00:00
#
#    metrics.train_mae  metrics.test_mae  metrics.training_duration  \
# 0         267.450256        276.514219                   0.651888
# 1         267.450256        276.514219                   0.644157
#
#   params.num_trees params.feature_fraction params.learning_rate  \
# 0                8      0.3962723889353149  0.09906308908786306
# 1                8      0.3962723889353149  0.09906308908786306
#
#   params.max_depth params.num_leaves tags.mlflow.user tags.mlflow.source.name  \
# 0                6                24          gabriel                train.py
# 1                6                24          gabriel                train.py
#
#   tags.mlflow.source.type             tags.mlflow.source.git.commit  \
# 0                   LOCAL  66e2bf008efc5aa702f8830dd6245d59c076c6ee
# 1                   LOCAL  66e2bf008efc5aa702f8830dd6245d59c076c6ee
#
#                 tags.mlflow.runName  \
# 0  TrialNumber35-20250504T064002UTC
# 1  TrialNumber35-20250504T063258UTC
#
#                        tags.mlflow.log-model.history
# 0  [{"run_id": "37cff3aa004b4ce39824c97d3f957fb5"...
# 1  [{"run_id": "1ffaae870c4041edabeb7a2041cfe926"...

# %%
sorted_runs_df = runs_df.sort_values(by="metrics.test_mae", ascending=True)
sorted_runs_df.head()
# Out:
#                              run_id       experiment_id    status  \
# 0  37cff3aa004b4ce39824c97d3f957fb5  255253755991586970  FINISHED
# 1  1ffaae870c4041edabeb7a2041cfe926  255253755991586970  FINISHED
#
#                                         artifact_uri  \
# 0  mlflow-artifacts:/255253755991586970/37cff3aa0...
# 1  mlflow-artifacts:/255253755991586970/1ffaae870...
#
#                         start_time                         end_time  \
# 0 2025-05-04 06:40:02.945000+00:00 2025-05-04 06:40:13.082000+00:00
# 1 2025-05-04 06:32:59.722000+00:00 2025-05-04 06:33:09.335000+00:00
#
#    metrics.train_mae  metrics.test_mae  metrics.training_duration  \
# 0         267.450256        276.514219                   0.651888
# 1         267.450256        276.514219                   0.644157
#
#   params.num_trees params.feature_fraction params.learning_rate  \
# 0                8      0.3962723889353149  0.09906308908786306
# 1                8      0.3962723889353149  0.09906308908786306
#
#   params.max_depth params.num_leaves tags.mlflow.user tags.mlflow.source.name  \
# 0                6                24          gabriel                train.py
# 1                6                24          gabriel                train.py
#
#   tags.mlflow.source.type             tags.mlflow.source.git.commit  \
# 0                   LOCAL  66e2bf008efc5aa702f8830dd6245d59c076c6ee
# 1                   LOCAL  66e2bf008efc5aa702f8830dd6245d59c076c6ee
#
#                 tags.mlflow.runName  \
# 0  TrialNumber35-20250504T064002UTC
# 1  TrialNumber35-20250504T063258UTC
#
#                        tags.mlflow.log-model.history
# 0  [{"run_id": "37cff3aa004b4ce39824c97d3f957fb5"...
# 1  [{"run_id": "1ffaae870c4041edabeb7a2041cfe926"...

# %%
best_run = sorted_runs_df.iloc[0]
best_run_id = best_run["run_id"]
best_run_id
# Out:
# '37cff3aa004b4ce39824c97d3f957fb5'

# %%
import mlflow

logged_model = f"runs:/{best_run_id}/lightgbm"

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)

# # Predict on a Pandas DataFrame.
# import pandas as pd

# loaded_model.predict(pd.DataFrame(data))
# Out:
# Downloading artifacts:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
loaded_model
# Out:
# mlflow.pyfunc.loaded_model:
#   artifact_path: lightgbm
#   flavor: mlflow.lightgbm
#   run_id: 37cff3aa004b4ce39824c97d3f957fb5

# %%
loaded_model.get_raw_model()
# Out:
# LGBMRegressor(feature_fraction=0.3962723889353149,
#               learning_rate=0.09906308908786306, max_depth=6, num_leaves=24,
#               num_trees=8, random_state=0)

# %% [markdown]
# # Save the model

# %%
import joblib
from utils import create_dir

# Create the models directory if it doesn't exist
create_dir("models")

# Save the model to a file
with open(f"models/{config['model_name']}.joblib", "wb") as f:
    joblib.dump(loaded_model, f)
# Out:
# Directory 'models' already exists.

# %%
# Load the model from the file
with open(f"models/{config['model_name']}.joblib", "rb") as f:
    loaded_model = joblib.load(f)

# %%
loaded_model
# Out:
# mlflow.pyfunc.loaded_model:
#   artifact_path: lightgbm
#   flavor: mlflow.lightgbm
#   run_id: 37cff3aa004b4ce39824c97d3f957fb5

# %% [markdown]
# # Load metadata

# %%
import json

metadata = best_run.to_json(indent=4)
with open(f"models/{config['model_name']}_metadata.json", "w") as f:
    f.write(metadata)

# %%
with open(f"models/{config['model_name']}_metadata.json", "r") as f:
    metadata = json.load(f)
metadata
# Out:
# {'run_id': '37cff3aa004b4ce39824c97d3f957fb5',
#  'experiment_id': '255253755991586970',
#  'status': 'FINISHED',
#  'artifact_uri': 'mlflow-artifacts:/255253755991586970/37cff3aa004b4ce39824c97d3f957fb5/artifacts',
#  'start_time': 1746340802945,
#  'end_time': 1746340813082,
#  'metrics.train_mae': 267.4502562879,
#  'metrics.test_mae': 276.5142190107,
#  'metrics.training_duration': 0.6518881321,
#  'params.num_trees': '8',
#  'params.feature_fraction': '0.3962723889353149',
#  'params.learning_rate': '0.09906308908786306',
#  'params.max_depth': '6',
#  'params.num_leaves': '24',
#  'tags.mlflow.user': 'gabriel',
#  'tags.mlflow.source.name': 'train.py',
#  'tags.mlflow.source.type': 'LOCAL',
#  'tags.mlflow.source.git.commit': '66e2bf008efc5aa702f8830dd6245d59c076c6ee',
#  'tags.mlflow.runName': 'TrialNumber35-20250504T064002UTC',
#  'tags.mlflow.log-model.history': '[{"run_id": "37cff3aa004b4ce39824c97d3f957fb5", "artifact_path": "lightgbm", "utc_time_created": "2025-05-04 06:40:06.358640", "model_uuid": "299063be05104442958c94a968a5d1a4", "flavors": {"python_function": {"loader_module": "mlflow.lightgbm", "python_version": "3.10.11", "data": "model.pkl", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}, "lightgbm": {"lgb_version": "4.5.0", "data": "model.pkl", "model_class": "lightgbm.sklearn.LGBMRegressor", "code": null}}}]'}

# %%
config["EXPERIMENT_ID"] = experiment_id
config["RUN_ID"] = best_run_id

# %%
config
# Out:
# {'splitting_datetime': datetime.datetime(2023, 1, 26, 5, 0),
#  'freq': 'H',
#  'id_col': 'prediction_unit_id',
#  'time_col': 'datetime',
#  'target_col': 'target',
#  'forecast_horizon': 48,
#  'n_lags': 4,
#  'rolling_mean_window_size': 4,
#  'date_features': ['month', 'dayofweek', 'hour'],
#  'static_features': ['county',
#   'is_business',
#   'product_type',
#   'is_consumption',
#   'prediction_unit_id'],
#  'n_lag_transforms': 4,
#  'model_name': 'lightgbm',
#  'hpo_config_version': 1,
#  'random_state': 0,
#  'n_splits': 5,
#  'scoring': 'neg_mean_absolute_error',
#  'n_trials': 3,
#  'studies_dir': './optuna_studies',
#  's3_bucket': None,
#  'EXPERIMENT_ID': '255253755991586970',
#  'RUN_ID': '37cff3aa004b4ce39824c97d3f957fb5'}

# %%
save_config(config, "../config/development/config.yaml")
# Out:
# Configuration saved to ../config/development/config.yaml

# %%
loaded_config = load_config("../config/development/config.yaml")
config == loaded_config
# Out:
# True
